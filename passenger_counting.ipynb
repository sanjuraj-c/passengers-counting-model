# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjuraj-c/passengers-counting-model/blob/main/passenger_counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ultralytics import YOLO
import cv2
import pandas as pd
import numpy as np
from tracker import Tracker

model = YOLO('yolov8s.pt')

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('WhatsApp Video 2024-07-20 at 2.01.08 PM.mp4')

my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")
print(class_list)
count = 0

# Define the circle area near the bus door where passengers enter
circle_center = (320, 300)  # Moved center of the circle to the right side
circle_radius = 80  # Radius of the circle
tracker = Tracker()
area_c = set()
total_capacity = 30  # Total capacity of the bus

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue
    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    # Bounding box
    a = results[0].boxes.data
    # Convert to dataframe
    px = pd.DataFrame(a).astype("float")
    # Rectangle coordinates
    list = []
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'person' in c:  # Focus on detecting persons
            list.append([x1, y1, x2, y2])
    bbox_id = tracker.update(list)
    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        # Centre point of object
        cx = int((x3 + x4) / 2)
        cy = int((y3 + y4) / 2)
        distance = np.sqrt((cx - circle_center[0]) ** 2 + (cy - circle_center[1]) ** 2)
        if distance <= circle_radius:
            if id not in area_c:  # Only add the ID if it hasn't been counted yet
                cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 2)
                cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0), 2)
                area_c.add(id)

    # Draw the circle area on the frame
    cv2.circle(frame, circle_center, circle_radius, (255, 255, 0), 3)
    passenger_count = len(area_c)
    cv2.putText(frame, f"Passenger Fillings: {passenger_count}", (61, 146), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 2)
    cv2.putText(frame, f"Passenger Capacity: {total_capacity}", (61, 200), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 2)

    cv2.imshow("RGB", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
#
# 0: 320x640 4 persons, 550.5ms
# Speed: 7.2ms preprocess, 550.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 174.88853593074649
# 284.96491012052695
# 110.4943437466371
# 319.7577207824699
# 144.9310180741169
# 35.608987629529715
#
# 0: 320x640 4 persons, 1 chair, 556.2ms
# Speed: 3.9ms preprocess, 556.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 32.2490309931942
# 196.1147623204332
# 6.708203932499369
# 307.6946538372092
# 114.17968295629481
# 41.773197148410844
# 341.11581610942636
# 145.90750494748377
# 35.38361202590826
#
# 0: 320x640 3 persons, 1 chair, 550.2ms
# Speed: 0.0ms preprocess, 550.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 25.632011235952593
# 212.8497122384712
# 8.54400374531753
# 332.2845166419886
# 122.12288892750614
# 36.87817782917155
#
# 0: 320x640 3 persons, 1 backpack, 553.4ms
# Speed: 0.0ms preprocess, 553.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 22.80350850198276
# 344.3617284194049
# 111.31936040060597
# 11.045361017187261
# 214.88834309938733
# 20.248456731316587
#
# 0: 320x640 3 persons, 548.6ms
# Speed: 17.6ms preprocess, 548.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 20.615528128088304
# 219.8590457543196
# 152.5909564816998
# 28.178005607210743
# 351.1267577385694
# 10.0
#
# 0: 320x640 4 persons, 1 chair, 532.5ms
# Speed: 13.6ms preprocess, 532.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 21.93171219946131
# 205.37283169883986
# 34.713109915419565
# 345.9739874614853
# 152.97058540778355
# 23.345235059857504
# 420.19281288475173
# 225.28204544525957
# 74.24284477308234
#
# 0: 320x640 4 persons, 1 bench, 1 chair, 554.4ms
# Speed: 0.0ms preprocess, 554.4ms inference, 15.7ms postprocess per image at shape (1, 3, 320, 640)
# 160.60199251565965
# 47.16990566028302
# 12.36931687685298
# 349.08451698693256
# 179.38784797192923
# 9.219544457292887
# 418.62632502029777
# 249.57563983690395
# 70.22819946431775
# 15.0
#
# 0: 320x640 4 persons, 1 chair, 545.7ms
# Speed: 5.0ms preprocess, 545.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 182.20043907740728
# 10.816653826391969
# 163.62457028209425
# 342.47627655065395
# 16.401219466856727
# 18.681541692269406
# 259.9423012901132
# 418.1506905411015
# 78.10249675906654
# 16.278820596099706
#
# 0: 320x640 4 persons, 1 chair, 555.4ms
# Speed: 13.4ms preprocess, 555.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 17.204650534085253
# 348.53981121243527
# 9.899494936611665
# 159.7904878270293
# 192.93781381574738
# 21.93171219946131
# 426.2980178232125
# 79.05694150420949
# 271.89152248645047
# 8.0
#
# 0: 320x640 4 persons, 1 chair, 531.9ms
# Speed: 7.0ms preprocess, 531.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 15.811388300841896
# 365.5311204261547
# 2.23606797749979
# 189.63649437806004
# 192.85486771144772
# 28.861739379323623
# 446.6956458261038
# 81.43709228600933
# 273.0805741901097
# 8.06225774829855
#
# 0: 320x640 4 persons, 1 chair, 533.8ms
# Speed: 5.5ms preprocess, 533.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 5.0
# 368.9078475717208
# 4.123105625617661
# 200.0
# 199.83242980057065
# 18.027756377319946
# 442.05995068542455
# 73.348483283569
# 270.51247660690257
# 4.123105625617661
#
# 0: 320x640 4 persons, 1 chair, 545.0ms
# Speed: 0.0ms preprocess, 545.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 16.278820596099706
# 364.72592449673766
# 2.23606797749979
# 215.94675269612182
# 197.42846805868703
# 15.033296378372908
# 434.234959440163
# 71.16881339463234
# 266.58019431308094
# 7.0710678118654755
#
# 0: 320x640 4 persons, 1 backpack, 1 handbag, 1 chair, 643.5ms
# Speed: 10.4ms preprocess, 643.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 27.294688127912362
# 351.0911562543266
# 17.46424919657298
# 255.08037948850554
# 206.90335908341362
# 41.617304093369626
# 448.0401767698964
# 98.00510190801293
# 291.61961525247233
# 16.278820596099706
#
# 0: 320x640 4 persons, 1 handbag, 1 chair, 522.4ms
# Speed: 2.5ms preprocess, 522.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 30.805843601498726
# 326.87918257362304
# 16.97056274847714
# 429.16779935125606
# 106.51291001564083
# 290.02758489495443
# 15.033296378372908
# 252.7152547829276
# 221.90313201935658
# 29.154759474226502
#
# 0: 320x640 5 persons, 1 chair, 519.8ms
# Speed: 9.5ms preprocess, 519.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 33.421549934136806
# 331.71674663785063
# 16.278820596099706
# 424.7940677551889
# 111.83022847155415
# 8.0
# 289.5047495292607
# 245.48930730278255
# 353.0056656769123
# 37.107950630558946
# 241.0082986123092
# 204.88289338058462
# 316.07752213657966
# 60.959002616512684
#
# 0: 320x640 4 persons, 1 handbag, 1 chair, 521.6ms
# Speed: 0.0ms preprocess, 521.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 302.8299853052864
# 29.154759474226502
# 53.225933528685054
# 428.9638679422779
# 125.686116973992
# 16.278820596099706
# 313.3209217399949
# 255.63450471327224
# 376.34027156285043
# 42.80186911806539
#
# 0: 320x640 4 persons, 1 chair, 541.0ms
# Speed: 2.3ms preprocess, 541.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# 15.524174696260024
# 373.75125417849773
# 61.40032573203501
# 484.78036263858706
# 366.742416417845
# 123.4908903522847
# 413.14646313383827
# 17.08800749063506
# 255.0
# 283.0282671395209
# 375.4530596492723
# 33.24154027718932
#
# 0: 320x640 4 persons, 1 chair, 515.1ms
# Speed: 1.9ms preprocess, 515.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
4ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 44.9221548904324
# 623.2439329829052
# 4.0
# 675.4317137949624
# 214.75800334329801
# 43.93176527297759
#
# 0: 320x640 3 persons, 1 chair, 1 potted plant, 537.2ms
# Speed: 6.2ms preprocess, 537.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 66.09841147864296
# 689.2967430649879
# 739.1244820732161
# 623.3393939099309
# 9.219544457292887
# 675.1629432959128
# 210.92415698539605
# 14.035668847618199
#
# 0: 320x640 4 persons, 1 chair, 1 potted plant, 528.3ms
# Speed: 4.0ms preprocess, 528.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 53.9351462406472
# 718.4719897114987
# 26.90724809414742
# 733.6136585424238
# 205.6817930688081
# 19.6468827043885
# 364.9287601710778
# 1081.177598732049
# 1077.248346482834
#
# 0: 320x640 3 persons, 540.5ms
# Speed: 4.0ms preprocess, 540.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 64.13267497929586
# 729.9486283294189
# 726.9731769467152
# 353.1600203873592
# 742.5099325934974
# 178.05897899291685
# 31.78049716414141
# 725.7837143391962
# 22.0
#
# 0: 320x640 1 person, 581.5ms
# Speed: 5.5ms preprocess, 581.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 103.00485425454472
# 637.3774391990981
# 647.7507236584148
#
# 0: 320x640 2 persons, 527.4ms
# Speed: 6.5ms preprocess, 527.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 174.54225849346628
# 216.0
# 328.97568299191965
#
# 0: 320x640 2 persons, 536.4ms
# Speed: 0.0ms preprocess, 536.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 100.46392387319938
# 399.7524233822729
# 598.6818854784234
# 290.01551682625535
# 681.2965580420909
#
# 0: 320x640 2 persons, 1 bench, 1 potted plant, 525.8ms
# Speed: 3.0ms preprocess, 525.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 36.359317925395686
# 908.4107000690822
# 201.0
#
# 0: 320x640 2 persons, 1 handbag, 1 potted plant, 594.6ms
# Speed: 4.0ms preprocess, 594.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 93.08598175880189
# 907.0198454278716
# 758.023746329889
# 231.36551169091732
# 777.048904509877
#
# 0: 320x640 2 persons, 1 handbag, 1 chair, 1 potted plant, 532.8ms
# Speed: 4.0ms preprocess, 532.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 10.198039027185569
# 759.9171007419164
# 24.186773244895647
#
# 0: 320x640 2 persons, 1 handbag, 1 chair, 1 potted plant, 538.4ms
# Speed: 4.8ms preprocess, 538.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 14.0
# 757.5466982305447
# 23.853720883753127
#
# 0: 320x640 2 persons, 1 handbag, 1 chair, 1 potted plant, 541.7ms
# Speed: 1.2ms preprocess, 541.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 5.0
# 760.9112957500369
# 26.570660511172846
#
# 0: 320x640 2 persons, 1 bench, 1 handbag, 1 chair, 1 potted plant, 595.9ms
# Speed: 0.0ms preprocess, 595.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 5.385164807134504
# 756.1692932141585
# 45.880278987817846
#
# 0: 320x640 2 persons, 1 bench, 1 potted plant, 524.9ms
# Speed: 5.0ms preprocess, 524.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 34.0147027033899
# 727.5554961650691
# 30.364452901377952
#
# 0: 320x640 2 persons, 1 bench, 526.7ms
# Speed: 6.0ms preprocess, 526.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 83.0
# 653.0696746902278
# 730.7667206434622
# 18.681541692269406
#
# 0: 320x640 1 person, 533.5ms
# Speed: 0.0ms preprocess, 533.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 190.0
# 500.37286097469354
#
# 0: 320x640 3 persons, 514.2ms
# Speed: 4.0ms preprocess, 514.2ms inference, 15.7ms postprocess per image at shape (1, 3, 320, 640)
# 372.9785516621566
# 177.02542190318317
# 520.5583540776192
# 256.78395588509807
# 552.8806381127847
# 103.71113729971339
#
# 0: 320x640 2 persons, 1 potted plant, 556.4ms
# Speed: 4.0ms preprocess, 556.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 30.675723300355934
# 709.9577452215026
# 290.99828178186897
# 203.57799488156869
#
# 0: 320x640 3 persons, 1 bench, 1 potted plant, 571.9ms
# Speed: 6.0ms preprocess, 571.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 62.80127387243033
# 742.1158939141513
# 523.6220010656542
# 317.34523787194286
# 575.0026086897345
# 946.5754063993
# 280.81488564533043
# 987.4943037810395
# 455.24169404833737
#
# 0: 320x640 2 persons, 1 bench, 1 potted plant, 540.5ms
# Speed: 4.0ms preprocess, 540.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 93.04837451562494
# 609.7097670203423
# 996.6629319885435
# 583.4552253600956
# 24.0
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 579.0ms
# Speed: 5.8ms preprocess, 579.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 93.23089616645332
# 619.2333970321691
#
# 0: 320x640 1 person, 1 bench, 1 chair, 1 potted plant, 532.8ms
# Speed: 4.0ms preprocess, 532.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 9.433981132056603
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 548.8ms
# Speed: 4.0ms preprocess, 548.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 5.0990195135927845
#
# 0: 320x640 1 person, 1 bench, 535.6ms
# Speed: 5.6ms preprocess, 535.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 6.082762530298219
#
# 0: 320x640 1 person, 1 chair, 523.1ms
# Speed: 5.9ms preprocess, 523.1ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 200.48940121612415
#
# 0: 320x640 2 persons, 1 potted plant, 530.5ms
# Speed: 3.0ms preprocess, 530.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 444.00112612469803
# 212.8966885604377
# 523.4137942393188
#
# 0: 320x640 2 persons, 1 potted plant, 540.6ms
# Speed: 5.0ms preprocess, 540.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 539.2086794553663
# 34.058772731852805
# 53.33854141237835
#
# 0: 320x640 2 persons, 2 benchs, 1 potted plant, 589.5ms
# Speed: 4.0ms preprocess, 589.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 45.967379738244816
# 669.032884094646
# 79.07591289387686
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 526.9ms
# Speed: 4.0ms preprocess, 526.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 72.86288492778748
# 714.5362132180566
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 541.0ms
# Speed: 4.0ms preprocess, 541.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 53.08483775994799
#
# 0: 320x640 1 person, 1 bench, 1 chair, 1 potted plant, 526.0ms
# Speed: 5.0ms preprocess, 526.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 60.83584469702052
#
# 0: 320x640 1 person, 642.3ms
# Speed: 4.0ms preprocess, 642.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 28.30194339616981
#
# 0: 320x640 1 person, 536.7ms
# Speed: 4.0ms preprocess, 536.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# 1.0
#
# 0: 320x640 1 person, 525.9ms
# Speed: 5.0ms preprocess, 525.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 12.041594578792296
#
# 0: 320x640 1 person, 591.8ms
# Speed: 5.0ms preprocess, 591.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 14.035668847618199
#
# 0: 320x640 1 person, 605.1ms
# Speed: 5.0ms preprocess, 605.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 71.0
#
# 0: 320x640 1 person, 543.4ms
# Speed: 0.0ms preprocess, 543.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4.123105625617661
#
# 0: 320x640 1 person, 541.6ms
# Speed: 3.0ms preprocess, 541.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 56.0357029044876
#
# 0: 320x640 1 person, 531.0ms
# Speed: 5.1ms preprocess, 531.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 123.1990259701756
#
# 0: 320x640 1 person, 1 potted plant, 527.9ms
# Speed: 4.1ms preprocess, 527.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 265.04716561397146
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 522.2ms
# Speed: 14.8ms preprocess, 522.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 528.0ms
# Speed: 4.0ms preprocess, 528.0ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 565.6ms
# Speed: 5.0ms preprocess, 565.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 592.9ms
# Speed: 5.0ms preprocess, 592.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 547.4ms
# Speed: 4.0ms preprocess, 547.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 568.6ms
# Speed: 4.0ms preprocess, 568.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 553.5ms
# Speed: 4.8ms preprocess, 553.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 538.1ms
# Speed: 4.3ms preprocess, 538.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 628.4ms
# Speed: 5.0ms preprocess, 628.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)

# %%
from ultralytics import YOLO
import cv2
import pandas as pd
import numpy as np
import math

class Tracker:
    def __init__(self):
        # Store the center positions of the objects
        self.center_points = {}
        # Keep the count of the IDs
        # each time a new object id detected, the count will increase by one
        self.id_count = 0

    def update(self, objects_rect):
        # Objects boxes and ids
        objects_bbs_ids = []

        # Get center point of new object
        for rect in objects_rect:
            x, y, w, h = rect
            cx = (x + x + w) // 2
            cy = (y + y + h) // 2

            # Find out if that object was detected already
            same_object_detected = False
            for id, pt in self.center_points.items():
                dist = math.hypot(cx - pt[0], cy - pt[1])
                print(dist)

                if dist < 60:
                    self.center_points[id] = (cx, cy)
                    objects_bbs_ids.append([x, y, w, h, id])
                    same_object_detected = True
                    break

            # New object is detected we assign the ID to that object
            if same_object_detected is False:
                self.center_points[self.id_count] = (cx, cy)
                objects_bbs_ids.append([x, y, w, h, self.id_count])
                self.id_count += 1

        # Clean the dictionary by center points to remove IDS not used anymore
        new_center_points = {}
        for obj_bb_id in objects_bbs_ids:
            _, _, _, _, object_id = obj_bb_id
            center = self.center_points[object_id]
            new_center_points[object_id] = center

        # Update dictionary with IDs not used removed
        self.center_points = new_center_points.copy()
        return objects_bbs_ids

model = YOLO('yolov8s.pt')

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('WhatsApp Video 2024-07-20 at 2.01.08 PM.mp4')

my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")
print(class_list)
count = 0

# Define the circle area near the bus door where passengers enter
circle_center = (320, 300)  # Moved center of the circle to the right side
circle_radius = 60  # Radius of the circle
tracker = Tracker()
area_c = set()
total_capacity = 30  # Total capacity of the bus

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue
    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    # Bounding box
    a = results[0].boxes.data
    # Convert to dataframe
    px = pd.DataFrame(a).astype("float")
    # Rectangle coordinates
    list = []
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'person' in c:  # Focus on detecting persons
            list.append([x1, y1, x2 - x1, y2 - y1])
    bbox_id = tracker.update(list)
    for bbox in bbox_id:
        x3, y3, w, h, id = bbox
        x4 = x3 + w
        y4 = y3 + h
        # Centre point of object
        cx = int((x3 + x4) / 2)
        cy = int((y3 + y4) / 2)
        distance = np.sqrt((cx - circle_center[0]) ** 2 + (cy - circle_center[1]) ** 2)
        if distance <= circle_radius:
            if id not in area_c:  # Only add the ID if it hasn't been counted yet
                cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 2)
                cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0), 2)
                area_c.add(id)

    # Draw the circle area on the frame
    cv2.circle(frame, circle_center, circle_radius, (255, 255, 0), 3)
    passenger_count = len(area_c)
    cv2.putText(frame, f"Passenger Fillings: {passenger_count}", (61, 146), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 2)
    cv2.putText(frame, f"Passenger Capacity: {total_capacity}", (61, 200), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 2)

    cv2.imshow("RGB", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
#
# 0: 320x640 4 persons, 577.7ms
# Speed: 11.7ms preprocess, 577.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 137.05838172107534
# 223.03362975121038
# 86.35392289873113
# 255.16269319788896
# 118.1905241548577
# 32.55764119219941
#
# 0: 320x640 4 persons, 1 chair, 569.6ms
# Speed: 0.0ms preprocess, 569.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 25.495097567963924
# 154.67385040788247
# 5.385164807134504
# 239.91039994131143
# 87.84645695758026
# 39.20459156782532
# 272.02941017470886
# 118.33849753989612
# 33.421549934136806
#
# 0: 320x640 3 persons, 1 chair, 602.3ms
# Speed: 14.0ms preprocess, 602.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 19.313207915827967
# 165.85837331892532
# 7.211102550927978
# 255.180328395431
# 91.3892772703669
# 36.87817782917155
#
# 0: 320x640 3 persons, 1 backpack, 583.5ms
# Speed: 0.0ms preprocess, 583.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 20.09975124224178
# 264.4730610100016
# 82.34682750416071
# 9.219544457292887
# 168.44286865284622
# 14.7648230602334
#
# 0: 320x640 3 persons, 555.7ms
# Speed: 6.3ms preprocess, 555.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 12.206555615733702
# 176.13914953808538
# 107.70329614269008
# 20.615528128088304
# 268.6037974415105
# 8.06225774829855
#
# 0: 320x640 4 persons, 1 chair, 578.4ms
# Speed: 0.0ms preprocess, 578.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 11.180339887498949
# 157.20687007888682
# 30.528675044947494
# 259.16982849089516
# 107.8563859954523
# 19.849433241279208
# 321.0763149159402
# 168.61791126686393
# 61.91122676865643
#
# 0: 320x640 4 persons, 1 bench, 1 chair, 572.4ms
# Speed: 0.0ms preprocess, 572.4ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 121.49485585818027
# 39.81205847478876
# 6.082762530298219
# 258.9710408520613
# 132.09844813622905
# 5.830951894845301
# 315.56932677305633
# 188.8279640307547
# 56.79788728465171
#
# 0: 320x640 4 persons, 1 chair, 595.1ms
# Speed: 5.6ms preprocess, 595.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# 133.13526955694348
# 6.4031242374328485
# 120.93386622447825
# 253.87004549572208
# 67.97793759742936
# 13.152946437965905
# 194.74342094150447
# 314.2117120668802
# 13.038404810405298
#
# 0: 320x640 4 persons, 1 chair, 539.7ms
# Speed: 12.7ms preprocess, 539.7ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 9.219544457292887
# 254.7174905655283
# 8.602325267042627
# 112.0714058089752
# 142.88806808127822
# 19.4164878389476
# 316.7917296900284
# 62.76941930590086
# 205.30221625691235
# 7.0
#
# 0: 320x640 4 persons, 1 chair, 536.5ms
# Speed: 13.5ms preprocess, 536.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 8.602325267042627
# 261.1991577321795
# 4.0
# 132.94359706281458
# 136.31214179228496
# 26.68332812825267
# 327.9054741842533
# 66.73080248281148
# 202.03960007879644
# 5.0
#
# 0: 320x640 4 persons, 1 chair, 536.2ms
# Speed: 10.4ms preprocess, 536.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2.23606797749979
# 261.1991577321795
# 2.23606797749979
# 141.0319112825179
# 138.27870407260838
# 14.866068747318506
# 324.48420608713764
# 63.28506932918696
# 198.65548066942426
# 3.605551275463989
#
# 0: 320x640 4 persons, 1 chair, 558.4ms
# Speed: 13.8ms preprocess, 558.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 7.810249675906654
# 257.6606295109907
# 2.23606797749979
# 152.12166183683374
# 136.5283853270081
# 14.142135623730951
# 316.62280397975127
# 59.50630218724736
#
# 0: 320x640 4 persons, 1 backpack, 1 handbag, 1 chair, 529.8ms
# Speed: 0.0ms preprocess, 529.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 14.422205101855956
# 247.40654801358835
# 69.77105417004964
# 128.09761902549164
# 183.14202139323461
# 207.03864373589778
# 37.12142238654117
# 326.0061349115995
# 15.033296378372908
#
# 0: 320x640 4 persons, 1 handbag, 1 chair, 525.7ms
# Speed: 0.0ms preprocess, 525.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 291.40521615098106
# 339.16662571662323
# 4.123105625617661
# 237.25513693068902
# 14.866068747318506
# 77.82030583337487
# 160.85397104206038
# 303.97532794620025
# 11.40175425099138
#
# 0: 320x640 4 persons, 1 chair, 528.0ms
# Speed: 9.1ms preprocess, 528.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 14.0
# 349.1847648452034
# 12.041594578792296
# 303.00660058817203
# 121.80722474467596
# 49.9799959983992
# 318.1351913888182
# 253.17977802344325
# 131.7459676802292
# 34.132096331752024
#
# 0: 320x640 3 persons, 527.6ms
# Speed: 1.2ms preprocess, 527.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 18.027756377319946
# 323.2336616133908
# 48.25971404805462
# 175.41379649275024
# 490.5527494571812
# 459.11654293871834
# 472.974629340729
#
# 0: 320x640 1 cat, 536.2ms
# Speed: 0.0ms preprocess, 536.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 528.0ms
# Speed: 6.6ms preprocess, 528.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 392.5366224952775
#
# 0: 320x640 5 persons, 1 potted plant, 589.0ms
# Speed: 0.0ms preprocess, 589.0ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 12.041594578792296
# 299.7749155616594
# 104.80935072788114
# 432.00925916003234
# 109.37092849564732
# 154.62535367784935
# 505.8903043150758
# 103.07764064044152
# 207.6968945362448
# 153.52198539622916
# 402.61271713645607
# 37.64306044943742
#
# 0: 320x640 5 persons, 1 handbag, 1 potted plant, 531.5ms
# Speed: 6.5ms preprocess, 531.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 34.17601498127012
# 430.2615483633182
# 138.3979768638256
# 179.86939706353607
# 107.62899237658968
# 109.41663493271945
# 320.3513695928269
# 30.23243291566195
# 437.43913862387757
# 160.89748288895012
# 20.518284528683193
# 347.3110997362451
# 150.0
# 296.627712798383
# 270.1184925176357
# 236.5417510715603
# 162.78820596099706
#
# 0: 320x640 5 persons, 1 handbag, 1 chair, 1 potted plant, 527.5ms
# Speed: 0.0ms preprocess, 527.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 46.389654018972806
# 434.8850422812907
# 7.211102550927978
# 424.09904503547284
# 157.8131806916013
# 158.52129194527782
# 12.041594578792296
# 328.5620184987912
# 108.15729286552988
# 13.038404810405298
# 371.13070473891
# 170.74249617479535
# 161.31026005806325
# 301.0548122850721
# 12.36931687685298
#
# 0: 320x640 5 persons, 1 handbag, 1 potted plant, 523.9ms
# Speed: 4.1ms preprocess, 523.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 11.0
# 334.63114021262277
# 106.10372283760829
# 139.84634424968
# 11.661903789690601
# 442.0542953077144
# 8.94427190999916
# 421.7226576791909
# 160.13119621110684
# 6.082762530298219
# 366.7642294444757
# 167.09278859364338
# 290.6303494131334
# 164.61470165206995
# 10.63014581273465
#
# 0: 320x640 5 persons, 1 handbag, 1 potted plant, 521.1ms
# Speed: 0.2ms preprocess, 521.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 45.0111097397076
# 433.34282040896903
# 114.23659658795863
# 6.324555320336759
# 428.8822682275405
# 129.3213052826177
# 157.91770008456936
# 8.0
# 342.14762895568924
# 18.35755975068582
# 337.6047985440965
# 167.09278859364338
# 152.2005256232711
# 269.3120866207085
# 15.0
#
# 0: 320x640 5 persons, 1 handbag, 1 potted plant, 529.9ms
# Speed: 0.0ms preprocess, 529.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 433.66461695646785
# 3.0
# 428.3223085481306
# 150.74813431681335
# 10.198039027185569
# 330.7234494256493
# 144.91721774861674
# 250.01199971201382
# 154.7804897265802
# 13.152946437965905
# 26.570660511172846
# 353.3072317403084
# 106.83164325236227
# 92.45539465060976
# 17.11724276862369
#
# 0: 320x640 4 persons, 1 handbag, 529.1ms
# Speed: 0.0ms preprocess, 529.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 6.324555320336759
# 375.2026119312071
# 373.5076973771759
# 285.82861998057507
# 57.0087712549569
# 103.04368005850722
# 45.39823785126467
# 149.01342221424215
# 46.2709412050371
#
# 0: 320x640 3 persons, 573.5ms
# Speed: 0.4ms preprocess, 573.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 309.38002521171273
# 82.34682750416071
# 303.78446306550967
# 35.05709628591621
# 154.434452114805
# 438.3263624287273
# 54.3323108288245
#
# 0: 320x640 1 person, 526.7ms
# Speed: 5.7ms preprocess, 526.7ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 17.11724276862369
#
# 0: 320x640 1 person, 585.5ms
# Speed: 4.0ms preprocess, 585.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 56.0
#
# 0: 320x640 1 person, 527.4ms
# Speed: 5.4ms preprocess, 527.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 46.010868281309364
#
# 0: 320x640 1 car, 519.6ms
# Speed: 6.7ms preprocess, 519.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 1 handbag, 1 potted plant, 533.4ms
# Speed: 2.4ms preprocess, 533.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 219.49487465542333
# 290.01551682625535
# 78.92401408950256
# 355.98033653560134
# 199.7298175035465
# 140.13208055259867
#
# 0: 320x640 6 persons, 2 handbags, 1 chair, 1 potted plant, 537.6ms
# Speed: 4.9ms preprocess, 537.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 22.47220505424423
# 283.5912551543154
# 61.84658438426491
# 17.08800749063506
# 107.01868995647442
# 130.61393493804556
# 177.9016582272352
# 255.906232827573
# 355.8440669731617
# 196.22945752358385
# 146.93195704134618
# 5.0990195135927845
# 344.5692963686695
# 151.34397906755325
# 93.72299611087985
# 63.0317380372777
# 238.37994882120435
# 269.69983314789056
# 65.52098900352466
# 95.34149149242423
# 242.26638231500465
# 180.71247881648904
# 187.3018953454556
#
# 0: 320x640 4 persons, 1 chair, 1 potted plant, 527.1ms
# Speed: 2.7ms preprocess, 527.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 24.186773244895647
# 300.647634283059
# 7.0710678118654755
# 360.672982076562
# 144.18044250174847
# 251.80349481291955
# 10.04987562112089
# 90.00555538409837
# 213.32135383031863
# 35.22782990761707
#
# 0: 320x640 3 persons, 1 chair, 1 potted plant, 532.4ms
# Speed: 5.1ms preprocess, 532.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 23.769728648009426
# 327.75753233144775
# 16.15549442140351
# 364.04670030093666
# 141.35416513141735
# 4.47213595499958
#
# 0: 320x640 4 persons, 1 chair, 1 potted plant, 526.6ms
# Speed: 6.9ms preprocess, 526.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 21.02379604162864
# 349.2678055590008
# 2.23606797749979
# 376.6974913640918
# 137.78606605894515
# 8.54400374531753
# 395.6829538911172
# 144.8481963988506
# 19.026297590440446
#
# 0: 320x640 3 persons, 1 chair, 1 potted plant, 588.1ms
# Speed: 4.4ms preprocess, 588.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 21.587033144922902
# 349.87140494758927
# 2.0
# 381.0774199555781
# 135.09256086106296
# 22.561028345356956
#
# 0: 320x640 3 persons, 1 chair, 1 potted plant, 536.9ms
# Speed: 5.0ms preprocess, 536.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 33.54101966249684
# 383.43839140075687
# 5.0990195135927845
# 411.5786680575173
# 130.50670480860362
# 10.0
#
# 0: 320x640 4 persons, 1 chair, 1 potted plant, 520.3ms
# Speed: 7.5ms preprocess, 520.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 28.792360097775937
# 391.57630163226173
# 12.727922061357855
# 401.04488526846967
# 124.95199078045935
# 13.152946437965905
# 349.91427521608773
# 739.9378352267169
# 732.5032423136432
#
# 0: 320x640 3 persons, 517.2ms
# Speed: 3.5ms preprocess, 517.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 35.35533905932738
# 389.9653830790625
# 103.4456378974
# 23.194827009486403
# 390.40107581818984
# 11.0
#
# 0: 320x640 1 person, 534.6ms
# Speed: 4.0ms preprocess, 534.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 69.00724599634447
# 321.7530108639234
# 328.97568299191965
#
# 0: 320x640 2 persons, 517.7ms
# Speed: 5.3ms preprocess, 517.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 119.6703806294607
# 159.0
# 260.5839595984373
#
# 0: 320x640 2 persons, 519.9ms
# Speed: 6.0ms preprocess, 519.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 61.98386886924694
# 313.0015974400131
# 412.4427232962172
# 157.01273833673497
# 467.736036670257
#
# 0: 320x640 2 persons, 1 bench, 1 potted plant, 604.6ms
# Speed: 6.5ms preprocess, 604.6ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
# 14.866068747318506
# 577.1698190307598
# 100.00499987500625
#
# 0: 320x640 2 persons, 1 handbag, 1 potted plant, 572.1ms
# Speed: 6.0ms preprocess, 572.1ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 46.09772228646444
# 451.2704289004543
# 162.24980739587951
#
# 0: 320x640 2 persons, 1 handbag, 1 chair, 1 potted plant, 527.9ms
# Speed: 6.0ms preprocess, 527.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 6.324555320336759
# 441.0260763265592
# 12.529964086141668
#
# 0: 320x640 2 persons, 1 handbag, 1 chair, 1 potted plant, 510.7ms
# Speed: 6.0ms preprocess, 510.7ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 14.035668847618199
# 446.0549293528769
# 11.661903789690601
#
# 0: 320x640 2 persons, 1 handbag, 1 chair, 1 potted plant, 527.9ms
# Speed: 8.7ms preprocess, 527.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 6.082762530298219
# 450.45976512891804
# 13.92838827718412
#
# 0: 320x640 2 persons, 1 bench, 1 handbag, 1 chair, 1 potted plant, 519.3ms
# Speed: 4.7ms preprocess, 519.3ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 6.324555320336759
# 442.7188724235731
# 22.847319317591726
#
# 0: 320x640 2 persons, 1 bench, 1 potted plant, 526.7ms
# Speed: 5.7ms preprocess, 526.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 34.058772731852805
# 411.50091129911243
# 15.524174696260024
#
# 0: 320x640 2 persons, 1 bench, 576.1ms
# Speed: 4.0ms preprocess, 576.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 72.0
# 345.70073763299956
# 412.1710809845834
# 9.486832980505138
#
# 0: 320x640 1 person, 524.1ms
# Speed: 6.0ms preprocess, 524.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 153.0
# 223.51733713517615
#
# 0: 320x640 3 persons, 524.8ms
# Speed: 5.0ms preprocess, 524.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 305.5503231875234
# 114.0175425099138
# 412.24871133819204
# 134.40610105199838
# 416.55971960812536
# 41.43669871020132
#
# 0: 320x640 2 persons, 1 potted plant, 517.2ms
# Speed: 3.6ms preprocess, 517.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 44.28317965096906
# 487.11497616065964
# 120.50726119201282
#
# 0: 320x640 3 persons, 1 bench, 1 potted plant, 537.9ms
# Speed: 4.0ms preprocess, 537.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 29.68164415931166
# 320.7054723574264
# 231.32660893204655
# 623.2848465990489
# 140.65560778013793
# 320.92366693654736
#
# 0: 320x640 2 persons, 1 bench, 1 potted plant, 534.3ms
# Speed: 2.7ms preprocess, 534.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 47.51841748206689
# 332.77770358003255
# 11.704699910719626
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 534.4ms
# Speed: 6.0ms preprocess, 534.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 66.03029607687671
# 308.13146544940844
#
# 0: 320x640 1 person, 1 bench, 1 chair, 1 potted plant, 592.6ms
# Speed: 6.3ms preprocess, 592.6ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
# 7.615773105863909
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 523.0ms
# Speed: 4.0ms preprocess, 523.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 5.0990195135927845
#
# 0: 320x640 1 person, 1 bench, 522.1ms
# Speed: 5.0ms preprocess, 522.1ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 6.082762530298219
#
# 0: 320x640 1 person, 1 chair, 534.3ms
# Speed: 0.0ms preprocess, 534.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 134.18271125595876
#
# 0: 320x640 2 persons, 1 potted plant, 562.2ms
# Speed: 6.6ms preprocess, 562.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 276.0018115882575
# 135.5912976558599
# 377.88093362857035
#
# 0: 320x640 2 persons, 1 potted plant, 562.2ms
# Speed: 5.0ms preprocess, 562.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 378.1282851096966
# 10.44030650891055
# 27.16615541441225
#
# 0: 320x640 2 persons, 2 benchs, 1 potted plant, 530.3ms
# Speed: 5.0ms preprocess, 530.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 16.1245154965971
# 429.35533069941033
# 39.96248240537617
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 597.6ms
# Speed: 4.6ms preprocess, 597.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 29.154759474226502
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 597.8ms
# Speed: 4.0ms preprocess, 597.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 27.459060435491963
#
# 0: 320x640 1 person, 1 bench, 1 chair, 1 potted plant, 561.4ms
# Speed: 4.7ms preprocess, 561.4ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 27.892651361962706
#
# 0: 320x640 1 person, 519.3ms
# Speed: 4.4ms preprocess, 519.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 26.570660511172846
#
# 0: 320x640 1 person, 535.3ms
# Speed: 5.8ms preprocess, 535.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2.23606797749979
#
# 0: 320x640 1 person, 517.2ms
# Speed: 4.0ms preprocess, 517.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 13.0
#
# 0: 320x640 1 person, 580.5ms
# Speed: 4.0ms preprocess, 580.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 14.035668847618199
#
# 0: 320x640 1 person, 524.0ms
# Speed: 5.0ms preprocess, 524.0ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 71.00704190430693
#
# 0: 320x640 1 person, 516.6ms
# Speed: 4.0ms preprocess, 516.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3.0
#
# 0: 320x640 1 person, 524.1ms
# Speed: 4.0ms preprocess, 524.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 51.0098029794274
#
# 0: 320x640 1 person, 522.2ms
# Speed: 5.8ms preprocess, 522.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 62.20128616033595
#
# 0: 320x640 1 person, 1 potted plant, 578.3ms
# Speed: 6.0ms preprocess, 578.3ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 133.06013678032951
#
# 0: 320x640 1 person, 1 bench, 1 potted plant, 522.9ms
# Speed: 6.0ms preprocess, 522.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 137.0
#
# 0: 320x640 1 bench, 1 potted plant, 521.9ms
# Speed: 6.0ms preprocess, 521.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 535.3ms
# Speed: 5.0ms preprocess, 535.3ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 528.3ms
# Speed: 4.0ms preprocess, 528.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 547.6ms
# Speed: 5.8ms preprocess, 547.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 592.3ms
# Speed: 4.0ms preprocess, 592.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 553.5ms
# Speed: 5.0ms preprocess, 553.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant, 557.1ms
# Speed: 6.0ms preprocess, 557.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bench, 1 potted plant,